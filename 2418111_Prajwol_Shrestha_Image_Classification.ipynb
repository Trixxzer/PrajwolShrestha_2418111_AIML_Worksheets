# %% [markdown]
# <a href="https://colab.research.google.com/github/Trixxzer/PrajwolShrestha_2418111_AIML_Worksheets/blob/main/2418111_Prajwol_Shrestha_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Facial Expression Classification Using CNN and Transfer Learning
#
# **Module:** Artificial Intelligence and Machine Learning (6CS012)
# **Assessment Part:** Part II – Vision Task
# **Dataset:** Facial Expression Image Dataset
# **Classes:** angry, disgust, fear, happy, neutral, sad, surprise
#
# This notebook is structured to follow the final portfolio requirements: data understanding, preprocessing, augmentation, baseline CNN, deeper CNN with regularisation, optimizer comparison, ablation study, transfer learning, evaluation, prediction, and comparative analysis.

# %% [markdown]
# ## 0. Runtime Setup
#
# Run this notebook in **Google Colab with GPU enabled**: `Runtime > Change runtime type > GPU`.
# Upload `facial expression classification(1).zip` to Colab, or keep it in the same working directory.

# %%
import os, zipfile, time, random, math, shutil
from pathlib import Path
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_recall_fscore_support
from sklearn.utils.class_weight import compute_class_weight

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print('TensorFlow version:', tf.__version__)
print('GPU devices:', tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Load and Extract Dataset
#
# The assessment requires an appropriate image dataset in image format, not a preloaded TensorFlow/PyTorch dataset. This section extracts the uploaded zip file and identifies the `train`, `validation`, and `test` folders.

# %%
import os
import zipfile
import shutil
from pathlib import Path

# ZIP file stored in your Google Drive
ZIP_PATH = Path("/content/drive/MyDrive/facial expression classification.zip")

# Where to extract inside Colab
EXTRACT_DIR = Path("/content/facial_expression_dataset")

# Remove old extracted dataset if it exists
if EXTRACT_DIR.exists():
    shutil.rmtree(EXTRACT_DIR)

EXTRACT_DIR.mkdir(parents=True, exist_ok=True)

# Extract ZIP to /content
with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_DIR)

print("Dataset extracted successfully to:", EXTRACT_DIR)

# Find dataset root containing train / validation / test folders
possible_roots = [EXTRACT_DIR] + [p for p in EXTRACT_DIR.rglob("*") if p.is_dir()]

dataset_root = None

for p in possible_roots:
    if (p / "train").exists() and (p / "validation").exists() and (p / "test").exists():
        dataset_root = p
        break

if dataset_root is None:
    raise FileNotFoundError("Could not find train, validation and test folders after extraction.")

TRAIN_DIR = dataset_root / "train"
VAL_DIR = dataset_root / "validation"
TEST_DIR = dataset_root / "test"

print("Dataset root:", dataset_root)
print("Train dir:", TRAIN_DIR)
print("Validation dir:", VAL_DIR)
print("Test dir:", TEST_DIR)

print("Train exists:", TRAIN_DIR.exists())
print("Validation exists:", VAL_DIR.exists())
print("Test exists:", TEST_DIR.exists())
# Out:
# Dataset extracted successfully to: /content/facial_expression_dataset
# Dataset root: /content/facial_expression_dataset/facial expression classification
# Train dir: /content/facial_expression_dataset/facial expression classification/train
# Validation dir: /content/facial_expression_dataset/facial expression classification/validation
# Test dir: /content/facial_expression_dataset/facial expression classification/test
# Train exists: True
# Validation exists: True
# Test exists: True

# %% [markdown]
# ## 2. Data Understanding, Analysis, Visualisation and Cleaning
#
# Required questions covered here:
# - What the dataset represents
# - Total image count
# - Class distribution
# - Train/validation/test split
# - Preprocessing methods
# - Data generators and augmentation visualisation

# %%
CLASSES = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
print('Classes:', CLASSES)

def count_images(split_dir):
    rows = []
    for cls in CLASSES:
        cls_dir = split_dir / cls
        count = len([p for p in cls_dir.glob('*') if p.suffix.lower() in ['.jpg','.jpeg','.png']])
        rows.append({'split': split_dir.name, 'class': cls, 'count': count})
    return rows

counts_df = pd.DataFrame(count_images(TRAIN_DIR) + count_images(VAL_DIR) + count_images(TEST_DIR))
display(counts_df)
print('Total images:', counts_df['count'].sum())
print('\nSplit totals:')
display(counts_df.groupby('split')['count'].sum().reset_index())
print('\nClass totals:')
display(counts_df.groupby('class')['count'].sum().reset_index())
# Out:
# Classes: ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
#          split     class  count
# 0        train     angry   3693
# 1        train   disgust    336
# 2        train      fear   3803
# 3        train     happy   6864
# 4        train   neutral   4682
# 5        train       sad   4638
# 6        train  surprise   2905
# 7   validation     angry    960
# 8   validation   disgust    111
# 9   validation      fear   1018
# 10  validation     happy   1825
# 11  validation   neutral   1216
# 12  validation       sad   1139
# 13  validation  surprise    797
# 14        test     angry    300
# 15        test   disgust    100
# 16        test      fear    300
# 17        test     happy    300
# 18        test   neutral    300
# 19        test       sad    300
# 20        test  surprise    300
# Total images: 35887
#
# Split totals:
#         split  count
# 0        test   1900
# 1       train  26921
# 2  validation   7066
# Class totals:
#       class  count
# 0     angry   4953
# 1   disgust    547
# 2      fear   5121
# 3     happy   8989
# 4   neutral   6198
# 5       sad   6077
# 6  surprise   4002

# %%
plt.figure(figsize=(10,5))
for split in counts_df['split'].unique():
    sub = counts_df[counts_df['split'] == split]
    plt.plot(sub['class'], sub['count'], marker='o', label=split)
plt.title('Class Distribution Across Train, Validation and Test Sets')
plt.xlabel('Emotion Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Show one sample image from each class
plt.figure(figsize=(12,6))
for i, cls in enumerate(CLASSES):
    img_path = next((TRAIN_DIR / cls).glob('*'))
    img = load_img(img_path, color_mode='grayscale')
    plt.subplot(2, 4, i+1)
    plt.imshow(img, cmap='gray')
    plt.title(cls)
    plt.axis('off')
plt.suptitle('Sample Facial Expression Images')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Preprocessing and Augmentation Choices
#
# - Images are resized to `64 × 64` for scratch CNN models because the dataset contains low-resolution grayscale face images.
# - Pixel values are normalised using `rescale=1./255`.
# - Training data uses augmentation: rotation, width/height shift, zoom and horizontal flip.
# - Validation and test data are only normalised, not augmented.
# - Class weighting is used because the dataset is imbalanced, especially the `disgust` class.

# %%
import os
from PIL import Image

valid_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")
bad_train_files = []

print("Checking train folder:", TRAIN_DIR)

for root, dirs, files in os.walk(TRAIN_DIR):
    for file in files:
        file_path = os.path.join(root, file)

        # Find hidden/system files or non-image files
        if file.startswith(".") or not file.lower().endswith(valid_extensions):
            bad_train_files.append(file_path)
            continue

        # Find corrupted image files
        try:
            with Image.open(file_path) as img:
                img.verify()
        except Exception:
            bad_train_files.append(file_path)

print("Bad files found in train folder:", len(bad_train_files))

for file in bad_train_files[:30]:
    print(file)

# Remove corrupted/non-image files from train folder only
for file in bad_train_files:
    os.remove(file)

print("Removed files from train folder:", len(bad_train_files))
# Out:
# Checking train folder: /content/facial_expression_dataset/facial expression classification/train
# Bad files found in train folder: 49
# /content/facial_expression_dataset/facial expression classification/train/surprise/20587.jpg
# /content/facial_expression_dataset/facial expression classification/train/surprise/18532.jpg
# /content/facial_expression_dataset/facial expression classification/train/surprise/19774.jpg
# /content/facial_expression_dataset/facial expression classification/train/surprise/21366.jpg
# /content/facial_expression_dataset/facial expression classification/train/surprise/33242.jpg
# /content/facial_expression_dataset/facial expression classification/train/surprise/32170.jpg
# /content/facial_expression_dataset/facial expression classification/train/surprise/9703.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/26089.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/34380.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/8887.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/15395.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/6171.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/8149.jpg
# /content/facial_expression_dataset/facial expression classification/train/angry/18369.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/9716.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/10538.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/19608.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/15361.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/29768.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/22118.jpg
# /content/facial_expression_dataset/facial expression classification/train/disgust/34687.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/12084.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/33154.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/19342.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/9799.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/12068.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/3568.jpg
# /content/facial_expression_dataset/facial expression classification/train/neutral/12023.jpg
# /content/facial_expression_dataset/facial expression classification/train/sad/21771.jpg
# /content/facial_expression_dataset/facial expression classification/train/sad/24610.jpg
# Removed files from train folder: 49

# %%
IMG_SIZE = (64, 64)
BATCH_SIZE = 64
NUM_CLASSES = len(CLASSES)
INPUT_SHAPE = (64, 64, 1)

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    TRAIN_DIR, target_size=IMG_SIZE, color_mode='grayscale', batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True, seed=SEED
)
val_gen = val_test_datagen.flow_from_directory(
    VAL_DIR, target_size=IMG_SIZE, color_mode='grayscale', batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
test_gen = val_test_datagen.flow_from_directory(
    TEST_DIR, target_size=IMG_SIZE, color_mode='grayscale', batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

idx_to_class = {v:k for k,v in train_gen.class_indices.items()}
print('Class indices:', train_gen.class_indices)

class_weights_values = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=train_gen.classes
)
class_weights = {i: w for i, w in enumerate(class_weights_values)}
print('Class weights:', class_weights)
# Out:
# Found 26872 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.
# Found 1900 images belonging to 7 classes.
# Class indices: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Class weights: {0: np.float64(1.0414696535152315), 1: np.float64(11.668258792878854), 2: np.float64(1.0112900797832305), 3: np.float64(0.559844996770766), 4: np.float64(0.8211459129106188), 5: np.float64(0.8289477743159454), 6: np.float64(1.3246573991915607)}

# %%
# Visualise augmented images from one training batch
images, labels = next(train_gen)
plt.figure(figsize=(10, 6))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(images[i].squeeze(), cmap='gray')
    plt.title(idx_to_class[np.argmax(labels[i])])
    plt.axis('off')
plt.suptitle('Sample Augmented Training Images')
plt.tight_layout()
plt.show()

# Reset generator after preview
train_gen.reset()

# %% [markdown]
# ## 3. Helper Functions for Training, Plotting and Evaluation

# %%
def get_callbacks(model_name, patience=4, monitor="val_loss", mode="min"):
    return [
        callbacks.EarlyStopping(
            monitor=monitor,
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),

        callbacks.ModelCheckpoint(
            filepath=f"{model_name}.keras",
            monitor=monitor,
            save_best_only=True,
            mode=mode,
            verbose=1
        ),

        callbacks.ReduceLROnPlateau(
            monitor=monitor,
            factor=0.5,
            patience=2,
            min_lr=1e-6,
            verbose=1
        )
    ]

def plot_history(history, title):
    hist = pd.DataFrame(history.history)
    plt.figure(figsize=(8,5))
    plt.plot(hist['loss'], label='Training Loss')
    plt.plot(hist['val_loss'], label='Validation Loss')
    plt.title(title + ' - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    plt.figure(figsize=(8,5))
    plt.plot(hist['accuracy'], label='Training Accuracy')
    plt.plot(hist['val_accuracy'], label='Validation Accuracy')
    plt.title(title + ' - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

def evaluate_model(model, generator, model_name):
    generator.reset()
    start = time.time()
    probs = model.predict(generator, verbose=1)
    pred = np.argmax(probs, axis=1)
    true = generator.classes
    elapsed = time.time() - start

    acc = accuracy_score(true, pred)
    precision, recall, f1, _ = precision_recall_fscore_support(true, pred, average='weighted', zero_division=0)
    print(f'\n{model_name} Evaluation')
    print(f'Accuracy: {acc:.4f} | Precision: {precision:.4f} | Recall: {recall:.4f} | F1-score: {f1:.4f}')
    print('\nClassification Report:')
    print(classification_report(true, pred, target_names=[idx_to_class[i] for i in range(NUM_CLASSES)], zero_division=0))

    cm = confusion_matrix(true, pred)
    disp = ConfusionMatrixDisplay(cm, display_labels=[idx_to_class[i] for i in range(NUM_CLASSES)])
    fig, ax = plt.subplots(figsize=(8, 8))
    disp.plot(ax=ax, xticks_rotation=45, cmap=None, colorbar=False)
    plt.title(model_name + ' Confusion Matrix')
    plt.show()

    return {'model': model_name, 'accuracy': acc, 'precision': precision, 'recall': recall, 'f1': f1, 'prediction_time_sec': elapsed}

def show_predictions(model, generator, model_name, n=8):
    generator.reset()
    imgs, labels = next(generator)
    probs = model.predict(imgs, verbose=0)
    preds = np.argmax(probs, axis=1)
    true = np.argmax(labels, axis=1)

    plt.figure(figsize=(12,6))
    for i in range(min(n, len(imgs))):
        plt.subplot(2, 4, i+1)
        plt.imshow(imgs[i].squeeze(), cmap='gray')
        plt.title(f'True: {idx_to_class[true[i]]}\nPred: {idx_to_class[preds[i]]}')
        plt.axis('off')
    plt.suptitle(model_name + ' Sample Predictions')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 4. Part A – Baseline CNN from Scratch
#
# Assessment requirement: baseline CNN with **three convolutional layers**, each followed by pooling, **three fully connected layers**, and an output layer suitable for multiclass classification.

# %%
def build_baseline_cnn(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES):
    model = models.Sequential(name='Baseline_CNN')
    model.add(layers.Input(shape=input_shape))

    model.add(layers.Conv2D(32, (3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2)))

    model.add(layers.Conv2D(64, (3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2)))

    model.add(layers.Conv2D(128, (3,3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2,2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    return model

baseline_model = build_baseline_cnn()
baseline_model.compile(optimizer=optimizers.Adam(learning_rate=5e-4), loss='categorical_crossentropy', metrics=['accuracy'])
baseline_model.summary()
# Out:
# Model: "Baseline_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 64, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,231,687 (8.51 MB)
#  Trainable params: 2,231,687 (8.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
BASELINE_EPOCHS = 20

start_time = time.time()
baseline_history = baseline_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=BASELINE_EPOCHS,
    callbacks=get_callbacks('baseline_cnn'),
    class_weight=class_weights,
    verbose=1
)
baseline_time = time.time() - start_time
print(f'Baseline training time: {baseline_time:.2f} seconds')

plot_history(baseline_history, 'Baseline CNN')
# Out:
# Epoch 1/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1388 - loss: 1.9575
# Epoch 1: val_loss improved from None to 1.79933, saving model to baseline_cnn.keras
#
# Epoch 1: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 42s 86ms/step - accuracy: 0.1812 - loss: 1.9115 - val_accuracy: 0.2900 - val_loss: 1.7993 - learning_rate: 5.0000e-04
# Epoch 2/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2583 - loss: 1.8379
# Epoch 2: val_loss improved from 1.79933 to 1.77405, saving model to baseline_cnn.keras
#
# Epoch 2: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 30s 71ms/step - accuracy: 0.2657 - loss: 1.8107 - val_accuracy: 0.2931 - val_loss: 1.7740 - learning_rate: 5.0000e-04
# Epoch 3/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3061 - loss: 1.7472
# Epoch 3: val_loss improved from 1.77405 to 1.64322, saving model to baseline_cnn.keras
#
# Epoch 3: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - accuracy: 0.3230 - loss: 1.7162 - val_accuracy: 0.3514 - val_loss: 1.6432 - learning_rate: 5.0000e-04
# Epoch 4/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.3616 - loss: 1.6194
# Epoch 4: val_loss improved from 1.64322 to 1.57764, saving model to baseline_cnn.keras
#
# Epoch 4: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.3681 - loss: 1.6148 - val_accuracy: 0.4048 - val_loss: 1.5776 - learning_rate: 5.0000e-04
# Epoch 5/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4087 - loss: 1.5501
# Epoch 5: val_loss improved from 1.57764 to 1.40415, saving model to baseline_cnn.keras
#
# Epoch 5: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.4072 - loss: 1.5398 - val_accuracy: 0.4733 - val_loss: 1.4041 - learning_rate: 5.0000e-04
# Epoch 6/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4215 - loss: 1.4771
# Epoch 6: val_loss improved from 1.40415 to 1.39892, saving model to baseline_cnn.keras
#
# Epoch 6: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.4211 - loss: 1.4916 - val_accuracy: 0.4704 - val_loss: 1.3989 - learning_rate: 5.0000e-04
# Epoch 7/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4478 - loss: 1.4269
# Epoch 7: val_loss did not improve from 1.39892
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.4460 - loss: 1.4369 - val_accuracy: 0.4673 - val_loss: 1.4118 - learning_rate: 5.0000e-04
# Epoch 8/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4464 - loss: 1.4206
# Epoch 8: val_loss improved from 1.39892 to 1.33358, saving model to baseline_cnn.keras
#
# Epoch 8: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.4525 - loss: 1.4110 - val_accuracy: 0.4982 - val_loss: 1.3336 - learning_rate: 5.0000e-04
# Epoch 9/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4799 - loss: 1.3409
# Epoch 9: val_loss improved from 1.33358 to 1.32783, saving model to baseline_cnn.keras
#
# Epoch 9: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 68ms/step - accuracy: 0.4761 - loss: 1.3560 - val_accuracy: 0.4946 - val_loss: 1.3278 - learning_rate: 5.0000e-04
# Epoch 10/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4883 - loss: 1.3103
# Epoch 10: val_loss did not improve from 1.32783
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.4835 - loss: 1.3404 - val_accuracy: 0.4955 - val_loss: 1.3362 - learning_rate: 5.0000e-04
# Epoch 11/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4930 - loss: 1.3029
# Epoch 11: val_loss improved from 1.32783 to 1.27227, saving model to baseline_cnn.keras
#
# Epoch 11: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - accuracy: 0.4931 - loss: 1.3072 - val_accuracy: 0.5301 - val_loss: 1.2723 - learning_rate: 5.0000e-04
# Epoch 12/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5005 - loss: 1.2907
# Epoch 12: val_loss did not improve from 1.27227
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.5015 - loss: 1.2930 - val_accuracy: 0.5200 - val_loss: 1.2862 - learning_rate: 5.0000e-04
# Epoch 13/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4980 - loss: 1.2981
# Epoch 13: val_loss did not improve from 1.27227
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 68ms/step - accuracy: 0.5019 - loss: 1.2841 - val_accuracy: 0.5083 - val_loss: 1.3038 - learning_rate: 5.0000e-04
# Epoch 14/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5194 - loss: 1.2276
# Epoch 14: val_loss improved from 1.27227 to 1.25064, saving model to baseline_cnn.keras
#
# Epoch 14: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.5284 - loss: 1.2085 - val_accuracy: 0.5309 - val_loss: 1.2506 - learning_rate: 2.5000e-04
# Epoch 15/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5317 - loss: 1.1932
# Epoch 15: val_loss improved from 1.25064 to 1.19913, saving model to baseline_cnn.keras
#
# Epoch 15: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 30s 71ms/step - accuracy: 0.5320 - loss: 1.1967 - val_accuracy: 0.5487 - val_loss: 1.1991 - learning_rate: 2.5000e-04
# Epoch 16/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5399 - loss: 1.1959
# Epoch 16: val_loss improved from 1.19913 to 1.18228, saving model to baseline_cnn.keras
#
# Epoch 16: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 30s 70ms/step - accuracy: 0.5378 - loss: 1.1853 - val_accuracy: 0.5587 - val_loss: 1.1823 - learning_rate: 2.5000e-04
# Epoch 17/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5436 - loss: 1.1583
# Epoch 17: val_loss did not improve from 1.18228
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 40s 69ms/step - accuracy: 0.5385 - loss: 1.1725 - val_accuracy: 0.5434 - val_loss: 1.2078 - learning_rate: 2.5000e-04
# Epoch 18/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5413 - loss: 1.1686
# Epoch 18: val_loss improved from 1.18228 to 1.14300, saving model to baseline_cnn.keras
#
# Epoch 18: finished saving model to baseline_cnn.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 70ms/step - accuracy: 0.5435 - loss: 1.1551 - val_accuracy: 0.5692 - val_loss: 1.1430 - learning_rate: 2.5000e-04
# Epoch 19/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5439 - loss: 1.1753
# Epoch 19: val_loss did not improve from 1.14300
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 69ms/step - accuracy: 0.5451 - loss: 1.1504 - val_accuracy: 0.5662 - val_loss: 1.1593 - learning_rate: 2.5000e-04
# Epoch 20/20
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5502 - loss: 1.1389
# Epoch 20: val_loss did not improve from 1.14300
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 29s 68ms/step - accuracy: 0.5505 - loss: 1.1390 - val_accuracy: 0.5631 - val_loss: 1.1630 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 18.
# Baseline training time: 610.28 seconds

# %%
from tensorflow.keras.models import load_model

best_baseline_cnn_model = load_model("baseline_cnn.keras")

baseline_test_loss, baseline_test_acc = best_baseline_cnn_model.evaluate(test_gen)

print("Best baseline CNN Test Accuracy:", baseline_test_acc)
print("Best baseline CNN Test Loss:", baseline_test_loss)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5337 - loss: 1.2363
# Best baseline CNN Test Accuracy: 0.5336841940879822
# Best baseline CNN Test Loss: 1.236255168914795

# %%
results = []
results.append(evaluate_model(baseline_model, test_gen, 'Baseline CNN'))
show_predictions(baseline_model, test_gen, 'Baseline CNN')
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step
#
# Baseline CNN Evaluation
# Accuracy: 0.5337 | Precision: 0.5318 | Recall: 0.5337 | F1-score: 0.5285
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.45      0.53      0.49       300
#      disgust       0.58      0.56      0.57       100
#         fear       0.41      0.26      0.32       300
#        happy       0.74      0.71      0.73       300
#      neutral       0.46      0.58      0.51       300
#          sad       0.41      0.38      0.39       300
#     surprise       0.72      0.72      0.72       300
#
#     accuracy                           0.53      1900
#    macro avg       0.54      0.54      0.53      1900
# weighted avg       0.53      0.53      0.53      1900

# %% [markdown]
# ## 5. Part A – Deeper CNN with Regularisation
#
# Assessment requirement: deeper architecture with at least double the convolutional layers compared with the baseline. This model uses six convolutional layers, Batch Normalisation and Dropout to reduce overfitting.

# %%
def build_deeper_cnn(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES):
    model = models.Sequential(name="Deeper_CNN_With_Regularisation")

    model.add(layers.Input(shape=input_shape))

    # Block 1
    model.add(layers.Conv2D(32, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Conv2D(32, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.15))

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Conv2D(64, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.20))

    # Block 3
    model.add(layers.Conv2D(128, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Conv2D(128, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))

    # Extra deeper feature layer
    model.add(layers.Conv2D(256, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Flatten())

    model.add(layers.Dense(256, activation="relu"))
    model.add(layers.Dropout(0.30))

    model.add(layers.Dense(128, activation="relu"))
    model.add(layers.Dropout(0.20))

    model.add(layers.Dense(num_classes, activation="softmax"))

    return model


deeper_adam_model = build_deeper_cnn(
    input_shape=INPUT_SHAPE,
    num_classes=NUM_CLASSES
)

deeper_adam_model.compile(
    optimizer=optimizers.Adam(learning_rate=3e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

deeper_adam_model.summary()
# Out:
# Model: "Deeper_CNN_With_Regularisation"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,812,775 (18.36 MB)
#  Trainable params: 4,811,367 (18.35 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
DEEPER_EPOCHS = 30

start_time = time.time()

deeper_adam_history = deeper_adam_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=DEEPER_EPOCHS,
    callbacks=get_callbacks("deeper_cnn_adam", patience=6),
    verbose=1
)

deeper_adam_time = time.time() - start_time

print(f"Deeper CNN with Adam training time: {deeper_adam_time:.2f} seconds")

plot_history(deeper_adam_history, "Deeper CNN with Adam")
# Out:
# Epoch 1/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.2236 - loss: 1.8976
# Epoch 1: val_loss improved from None to 1.90036, saving model to deeper_cnn_adam.keras
#
# Epoch 1: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 58s 102ms/step - accuracy: 0.2422 - loss: 1.8274 - val_accuracy: 0.2583 - val_loss: 1.9004 - learning_rate: 3.0000e-04
# Epoch 2/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2856 - loss: 1.7397
# Epoch 2: val_loss improved from 1.90036 to 1.58764, saving model to deeper_cnn_adam.keras
#
# Epoch 2: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.2946 - loss: 1.7188 - val_accuracy: 0.3634 - val_loss: 1.5876 - learning_rate: 3.0000e-04
# Epoch 3/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3403 - loss: 1.6329
# Epoch 3: val_loss improved from 1.58764 to 1.58414, saving model to deeper_cnn_adam.keras
#
# Epoch 3: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 80ms/step - accuracy: 0.3496 - loss: 1.6074 - val_accuracy: 0.3927 - val_loss: 1.5841 - learning_rate: 3.0000e-04
# Epoch 4/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3722 - loss: 1.5464
# Epoch 4: val_loss improved from 1.58414 to 1.44613, saving model to deeper_cnn_adam.keras
#
# Epoch 4: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.3813 - loss: 1.5330 - val_accuracy: 0.4295 - val_loss: 1.4461 - learning_rate: 3.0000e-04
# Epoch 5/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4052 - loss: 1.4859
# Epoch 5: val_loss improved from 1.44613 to 1.36955, saving model to deeper_cnn_adam.keras
#
# Epoch 5: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.4059 - loss: 1.4844 - val_accuracy: 0.4406 - val_loss: 1.3696 - learning_rate: 3.0000e-04
# Epoch 6/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4194 - loss: 1.4525
# Epoch 6: val_loss did not improve from 1.36955
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.4248 - loss: 1.4451 - val_accuracy: 0.4077 - val_loss: 1.4955 - learning_rate: 3.0000e-04
# Epoch 7/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4383 - loss: 1.4157
# Epoch 7: val_loss improved from 1.36955 to 1.36516, saving model to deeper_cnn_adam.keras
#
# Epoch 7: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 79ms/step - accuracy: 0.4373 - loss: 1.4143 - val_accuracy: 0.4721 - val_loss: 1.3652 - learning_rate: 3.0000e-04
# Epoch 8/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4456 - loss: 1.3843
# Epoch 8: val_loss improved from 1.36516 to 1.28076, saving model to deeper_cnn_adam.keras
#
# Epoch 8: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.4456 - loss: 1.3867 - val_accuracy: 0.5127 - val_loss: 1.2808 - learning_rate: 3.0000e-04
# Epoch 9/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4530 - loss: 1.3711
# Epoch 9: val_loss did not improve from 1.28076
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.4587 - loss: 1.3648 - val_accuracy: 0.4738 - val_loss: 1.3366 - learning_rate: 3.0000e-04
# Epoch 10/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4677 - loss: 1.3470
# Epoch 10: val_loss did not improve from 1.28076
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 30s 72ms/step - accuracy: 0.4683 - loss: 1.3419 - val_accuracy: 0.4858 - val_loss: 1.3339 - learning_rate: 3.0000e-04
# Epoch 11/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4802 - loss: 1.3161
# Epoch 11: val_loss improved from 1.28076 to 1.24227, saving model to deeper_cnn_adam.keras
#
# Epoch 11: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.4839 - loss: 1.3066 - val_accuracy: 0.5083 - val_loss: 1.2423 - learning_rate: 1.5000e-04
# Epoch 12/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4925 - loss: 1.2924
# Epoch 12: val_loss improved from 1.24227 to 1.22517, saving model to deeper_cnn_adam.keras
#
# Epoch 12: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.4905 - loss: 1.2873 - val_accuracy: 0.5345 - val_loss: 1.2252 - learning_rate: 1.5000e-04
# Epoch 13/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4906 - loss: 1.2901
# Epoch 13: val_loss improved from 1.22517 to 1.19713, saving model to deeper_cnn_adam.keras
#
# Epoch 13: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.4947 - loss: 1.2808 - val_accuracy: 0.5324 - val_loss: 1.1971 - learning_rate: 1.5000e-04
# Epoch 14/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4996 - loss: 1.2695
# Epoch 14: val_loss improved from 1.19713 to 1.18367, saving model to deeper_cnn_adam.keras
#
# Epoch 14: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 30s 72ms/step - accuracy: 0.4989 - loss: 1.2693 - val_accuracy: 0.5422 - val_loss: 1.1837 - learning_rate: 1.5000e-04
# Epoch 15/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5078 - loss: 1.2557
# Epoch 15: val_loss did not improve from 1.18367
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5048 - loss: 1.2576 - val_accuracy: 0.5320 - val_loss: 1.2151 - learning_rate: 1.5000e-04
# Epoch 16/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5023 - loss: 1.2592
# Epoch 16: val_loss improved from 1.18367 to 1.18083, saving model to deeper_cnn_adam.keras
#
# Epoch 16: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 81ms/step - accuracy: 0.5048 - loss: 1.2557 - val_accuracy: 0.5396 - val_loss: 1.1808 - learning_rate: 1.5000e-04
# Epoch 17/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5080 - loss: 1.2492
# Epoch 17: val_loss improved from 1.18083 to 1.17568, saving model to deeper_cnn_adam.keras
#
# Epoch 17: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 79ms/step - accuracy: 0.5073 - loss: 1.2486 - val_accuracy: 0.5558 - val_loss: 1.1757 - learning_rate: 1.5000e-04
# Epoch 18/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5091 - loss: 1.2445
# Epoch 18: val_loss did not improve from 1.17568
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 38s 90ms/step - accuracy: 0.5084 - loss: 1.2445 - val_accuracy: 0.5236 - val_loss: 1.2254 - learning_rate: 1.5000e-04
# Epoch 19/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5177 - loss: 1.2224
# Epoch 19: val_loss improved from 1.17568 to 1.16620, saving model to deeper_cnn_adam.keras
#
# Epoch 19: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5148 - loss: 1.2363 - val_accuracy: 0.5491 - val_loss: 1.1662 - learning_rate: 1.5000e-04
# Epoch 20/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5196 - loss: 1.2288
# Epoch 20: val_loss improved from 1.16620 to 1.14632, saving model to deeper_cnn_adam.keras
#
# Epoch 20: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.5196 - loss: 1.2274 - val_accuracy: 0.5626 - val_loss: 1.1463 - learning_rate: 1.5000e-04
# Epoch 21/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5202 - loss: 1.2153
# Epoch 21: val_loss improved from 1.14632 to 1.14374, saving model to deeper_cnn_adam.keras
#
# Epoch 21: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 78ms/step - accuracy: 0.5199 - loss: 1.2177 - val_accuracy: 0.5548 - val_loss: 1.1437 - learning_rate: 1.5000e-04
# Epoch 22/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5206 - loss: 1.2132
# Epoch 22: val_loss improved from 1.14374 to 1.12799, saving model to deeper_cnn_adam.keras
#
# Epoch 22: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 35s 83ms/step - accuracy: 0.5241 - loss: 1.2121 - val_accuracy: 0.5686 - val_loss: 1.1280 - learning_rate: 1.5000e-04
# Epoch 23/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5301 - loss: 1.2025
# Epoch 23: val_loss did not improve from 1.12799
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.5279 - loss: 1.2086 - val_accuracy: 0.5365 - val_loss: 1.2062 - learning_rate: 1.5000e-04
# Epoch 24/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5222 - loss: 1.2162
# Epoch 24: val_loss did not improve from 1.12799
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.5214 - loss: 1.2108 - val_accuracy: 0.5211 - val_loss: 1.2205 - learning_rate: 1.5000e-04
# Epoch 25/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5270 - loss: 1.1967
# Epoch 25: val_loss did not improve from 1.12799
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.5335 - loss: 1.1865 - val_accuracy: 0.5676 - val_loss: 1.1424 - learning_rate: 7.5000e-05
# Epoch 26/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5358 - loss: 1.1878
# Epoch 26: val_loss improved from 1.12799 to 1.10906, saving model to deeper_cnn_adam.keras
#
# Epoch 26: finished saving model to deeper_cnn_adam.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 35s 83ms/step - accuracy: 0.5358 - loss: 1.1834 - val_accuracy: 0.5787 - val_loss: 1.1091 - learning_rate: 7.5000e-05
# Epoch 27/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5397 - loss: 1.1814
# Epoch 27: val_loss did not improve from 1.10906
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.5413 - loss: 1.1803 - val_accuracy: 0.5427 - val_loss: 1.1815 - learning_rate: 7.5000e-05
# Epoch 28/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5399 - loss: 1.1821
# Epoch 28: val_loss did not improve from 1.10906
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 42s 75ms/step - accuracy: 0.5374 - loss: 1.1799 - val_accuracy: 0.5521 - val_loss: 1.1619 - learning_rate: 7.5000e-05
# Epoch 29/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5382 - loss: 1.1768
# Epoch 29: val_loss did not improve from 1.10906
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 82ms/step - accuracy: 0.5432 - loss: 1.1689 - val_accuracy: 0.5785 - val_loss: 1.1101 - learning_rate: 3.7500e-05
# Epoch 30/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5424 - loss: 1.1631
# Epoch 30: val_loss did not improve from 1.10906
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 79ms/step - accuracy: 0.5442 - loss: 1.1596 - val_accuracy: 0.5778 - val_loss: 1.1131 - learning_rate: 3.7500e-05
# Restoring model weights from the end of the best epoch: 26.
# Deeper CNN with Adam training time: 1002.94 seconds

# %%
from tensorflow.keras.models import load_model

best_deeper_adam_model = load_model("deeper_cnn_adam.keras")

deeper_test_loss, deeper_test_acc = best_deeper_adam_model.evaluate(test_gen)

print("Best Deeper CNN Test Accuracy:", deeper_test_acc)
print("Best Deeper CNN Test Loss:", deeper_test_loss)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - accuracy: 0.5158 - loss: 1.2899
# Best Deeper CNN Test Accuracy: 0.5157894492149353
# Best Deeper CNN Test Loss: 1.2899391651153564

# %%
results.append(evaluate_model(deeper_adam_model, test_gen, 'Deeper CNN with Adam'))
show_predictions(deeper_adam_model, test_gen, 'Deeper CNN with Adam')
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
#
# Deeper CNN with Adam Evaluation
# Accuracy: 0.5158 | Precision: 0.4857 | Recall: 0.5158 | F1-score: 0.4901
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.39      0.37      0.38       300
#      disgust       0.00      0.00      0.00       100
#         fear       0.38      0.21      0.27       300
#        happy       0.72      0.85      0.78       300
#      neutral       0.46      0.74      0.57       300
#          sad       0.34      0.39      0.36       300
#     surprise       0.78      0.71      0.74       300
#
#     accuracy                           0.52      1900
#    macro avg       0.44      0.47      0.44      1900
# weighted avg       0.49      0.52      0.49      1900

# %% [markdown]
# ## 6. Optimizer Analysis – SGD vs Adam
#
# The same deeper architecture is trained with SGD and Adam so convergence speed and final performance can be compared.

# %%
deeper_sgd_model = build_deeper_cnn(
    input_shape=INPUT_SHAPE,
    num_classes=NUM_CLASSES
)

deeper_sgd_model.compile(
    optimizer=optimizers.SGD(
        learning_rate=0.001,
        momentum=0.9,
        nesterov=True
    ),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

deeper_sgd_model.summary()
# Out:
# Model: "Deeper_CNN_With_Regularisation"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 64, 64, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,812,775 (18.36 MB)
#  Trainable params: 4,811,367 (18.35 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
DEEPER_EPOCHS = 30

start_time = time.time()

deeper_sgd_history = deeper_sgd_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=DEEPER_EPOCHS,
    callbacks=get_callbacks("deeper_cnn_sgd", patience=6),
    verbose=1
)

deeper_sgd_time = time.time() - start_time

print(f"Deeper CNN with SGD training time: {deeper_sgd_time:.2f} seconds")

plot_history(deeper_sgd_history, "Deeper CNN with SGD")
# Out:
# Epoch 1/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.2238 - loss: 1.8687
# Epoch 1: val_loss improved from None to 1.87846, saving model to deeper_cnn_sgd.keras
#
# Epoch 1: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 50s 94ms/step - accuracy: 0.2388 - loss: 1.8277 - val_accuracy: 0.2583 - val_loss: 1.8785 - learning_rate: 0.0010
# Epoch 2/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2616 - loss: 1.7746
# Epoch 2: val_loss improved from 1.87846 to 1.66895, saving model to deeper_cnn_sgd.keras
#
# Epoch 2: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.2682 - loss: 1.7626 - val_accuracy: 0.3428 - val_loss: 1.6690 - learning_rate: 0.0010
# Epoch 3/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2948 - loss: 1.7269
# Epoch 3: val_loss improved from 1.66895 to 1.61456, saving model to deeper_cnn_sgd.keras
#
# Epoch 3: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - accuracy: 0.3018 - loss: 1.7182 - val_accuracy: 0.3578 - val_loss: 1.6146 - learning_rate: 0.0010
# Epoch 4/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3313 - loss: 1.6769
# Epoch 4: val_loss improved from 1.61456 to 1.58224, saving model to deeper_cnn_sgd.keras
#
# Epoch 4: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.3300 - loss: 1.6717 - val_accuracy: 0.3753 - val_loss: 1.5822 - learning_rate: 0.0010
# Epoch 5/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.3507 - loss: 1.6352
# Epoch 5: val_loss did not improve from 1.58224
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.3527 - loss: 1.6334 - val_accuracy: 0.2253 - val_loss: 2.3509 - learning_rate: 0.0010
# Epoch 6/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3628 - loss: 1.6088
# Epoch 6: val_loss improved from 1.58224 to 1.48072, saving model to deeper_cnn_sgd.keras
#
# Epoch 6: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.3696 - loss: 1.5972 - val_accuracy: 0.4229 - val_loss: 1.4807 - learning_rate: 0.0010
# Epoch 7/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3835 - loss: 1.5752
# Epoch 7: val_loss improved from 1.48072 to 1.47073, saving model to deeper_cnn_sgd.keras
#
# Epoch 7: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 80ms/step - accuracy: 0.3828 - loss: 1.5743 - val_accuracy: 0.4399 - val_loss: 1.4707 - learning_rate: 0.0010
# Epoch 8/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4037 - loss: 1.5358
# Epoch 8: val_loss did not improve from 1.47073
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.4021 - loss: 1.5384 - val_accuracy: 0.4185 - val_loss: 1.5283 - learning_rate: 0.0010
# Epoch 9/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4093 - loss: 1.5168
# Epoch 9: val_loss improved from 1.47073 to 1.44600, saving model to deeper_cnn_sgd.keras
#
# Epoch 9: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.4109 - loss: 1.5124 - val_accuracy: 0.4424 - val_loss: 1.4460 - learning_rate: 0.0010
# Epoch 10/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4200 - loss: 1.4963
# Epoch 10: val_loss improved from 1.44600 to 1.36015, saving model to deeper_cnn_sgd.keras
#
# Epoch 10: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.4234 - loss: 1.4881 - val_accuracy: 0.4768 - val_loss: 1.3602 - learning_rate: 0.0010
# Epoch 11/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4329 - loss: 1.4700
# Epoch 11: val_loss did not improve from 1.36015
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 81ms/step - accuracy: 0.4379 - loss: 1.4628 - val_accuracy: 0.4601 - val_loss: 1.3963 - learning_rate: 0.0010
# Epoch 12/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4426 - loss: 1.4450
# Epoch 12: val_loss improved from 1.36015 to 1.35750, saving model to deeper_cnn_sgd.keras
#
# Epoch 12: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.4425 - loss: 1.4437 - val_accuracy: 0.4786 - val_loss: 1.3575 - learning_rate: 0.0010
# Epoch 13/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4495 - loss: 1.4206
# Epoch 13: val_loss improved from 1.35750 to 1.34597, saving model to deeper_cnn_sgd.keras
#
# Epoch 13: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.4493 - loss: 1.4208 - val_accuracy: 0.4839 - val_loss: 1.3460 - learning_rate: 0.0010
# Epoch 14/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4574 - loss: 1.4046
# Epoch 14: val_loss did not improve from 1.34597
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.4563 - loss: 1.4063 - val_accuracy: 0.4672 - val_loss: 1.3667 - learning_rate: 0.0010
# Epoch 15/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4627 - loss: 1.4051
# Epoch 15: val_loss improved from 1.34597 to 1.34104, saving model to deeper_cnn_sgd.keras
#
# Epoch 15: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 81ms/step - accuracy: 0.4638 - loss: 1.3967 - val_accuracy: 0.4699 - val_loss: 1.3410 - learning_rate: 0.0010
# Epoch 16/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4661 - loss: 1.3880
# Epoch 16: val_loss did not improve from 1.34104
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.4709 - loss: 1.3781 - val_accuracy: 0.4836 - val_loss: 1.3433 - learning_rate: 0.0010
# Epoch 17/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4775 - loss: 1.3630
# Epoch 17: val_loss improved from 1.34104 to 1.25755, saving model to deeper_cnn_sgd.keras
#
# Epoch 17: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.4788 - loss: 1.3593 - val_accuracy: 0.5059 - val_loss: 1.2575 - learning_rate: 0.0010
# Epoch 18/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4797 - loss: 1.3480
# Epoch 18: val_loss did not improve from 1.25755
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.4857 - loss: 1.3414 - val_accuracy: 0.4931 - val_loss: 1.3042 - learning_rate: 0.0010
# Epoch 19/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4857 - loss: 1.3306
# Epoch 19: val_loss improved from 1.25755 to 1.24197, saving model to deeper_cnn_sgd.keras
#
# Epoch 19: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - accuracy: 0.4898 - loss: 1.3274 - val_accuracy: 0.5180 - val_loss: 1.2420 - learning_rate: 0.0010
# Epoch 20/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4879 - loss: 1.3298
# Epoch 20: val_loss did not improve from 1.24197
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - accuracy: 0.4947 - loss: 1.3176 - val_accuracy: 0.5197 - val_loss: 1.2480 - learning_rate: 0.0010
# Epoch 21/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5078 - loss: 1.3008
# Epoch 21: val_loss improved from 1.24197 to 1.23414, saving model to deeper_cnn_sgd.keras
#
# Epoch 21: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 80ms/step - accuracy: 0.5044 - loss: 1.3029 - val_accuracy: 0.5239 - val_loss: 1.2341 - learning_rate: 0.0010
# Epoch 22/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5042 - loss: 1.2928
# Epoch 22: val_loss did not improve from 1.23414
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5024 - loss: 1.2955 - val_accuracy: 0.5089 - val_loss: 1.2559 - learning_rate: 0.0010
# Epoch 23/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5104 - loss: 1.2784
# Epoch 23: val_loss improved from 1.23414 to 1.20008, saving model to deeper_cnn_sgd.keras
#
# Epoch 23: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - accuracy: 0.5093 - loss: 1.2866 - val_accuracy: 0.5321 - val_loss: 1.2001 - learning_rate: 0.0010
# Epoch 24/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5149 - loss: 1.2721
# Epoch 24: val_loss improved from 1.20008 to 1.17582, saving model to deeper_cnn_sgd.keras
#
# Epoch 24: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 35s 83ms/step - accuracy: 0.5112 - loss: 1.2787 - val_accuracy: 0.5415 - val_loss: 1.1758 - learning_rate: 0.0010
# Epoch 25/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5137 - loss: 1.2707
# Epoch 25: val_loss did not improve from 1.17582
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 78ms/step - accuracy: 0.5147 - loss: 1.2666 - val_accuracy: 0.5317 - val_loss: 1.2337 - learning_rate: 0.0010
# Epoch 26/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5188 - loss: 1.2635
# Epoch 26: val_loss improved from 1.17582 to 1.14217, saving model to deeper_cnn_sgd.keras
#
# Epoch 26: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5173 - loss: 1.2609 - val_accuracy: 0.5569 - val_loss: 1.1422 - learning_rate: 0.0010
# Epoch 27/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5206 - loss: 1.2494
# Epoch 27: val_loss improved from 1.14217 to 1.13807, saving model to deeper_cnn_sgd.keras
#
# Epoch 27: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5207 - loss: 1.2503 - val_accuracy: 0.5610 - val_loss: 1.1381 - learning_rate: 0.0010
# Epoch 28/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5291 - loss: 1.2239
# Epoch 28: val_loss did not improve from 1.13807
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 40s 73ms/step - accuracy: 0.5274 - loss: 1.2362 - val_accuracy: 0.5399 - val_loss: 1.1709 - learning_rate: 0.0010
# Epoch 29/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5284 - loss: 1.2350
# Epoch 29: val_loss improved from 1.13807 to 1.13125, saving model to deeper_cnn_sgd.keras
#
# Epoch 29: finished saving model to deeper_cnn_sgd.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 77ms/step - accuracy: 0.5282 - loss: 1.2338 - val_accuracy: 0.5643 - val_loss: 1.1312 - learning_rate: 0.0010
# Epoch 30/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5342 - loss: 1.2187
# Epoch 30: val_loss did not improve from 1.13125
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5336 - loss: 1.2237 - val_accuracy: 0.5484 - val_loss: 1.1747 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 29.
# Deeper CNN with SGD training time: 998.44 seconds

# %%
from tensorflow.keras.models import load_model

best_deeper_sgd_model = load_model("deeper_cnn_sgd.keras")

results.append(
    evaluate_model(best_deeper_sgd_model, test_gen, "Deeper CNN with SGD")
)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step
#
# Deeper CNN with SGD Evaluation
# Accuracy: 0.5011 | Precision: 0.5429 | Recall: 0.5011 | F1-score: 0.4773
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.54      0.26      0.35       300
#      disgust       0.93      0.13      0.23       100
#         fear       0.41      0.15      0.22       300
#        happy       0.65      0.83      0.73       300
#      neutral       0.43      0.58      0.50       300
#          sad       0.32      0.62      0.42       300
#     surprise       0.77      0.69      0.73       300
#
#     accuracy                           0.50      1900
#    macro avg       0.58      0.47      0.45      1900
# weighted avg       0.54      0.50      0.48      1900

# %% [markdown]
# ## 7. Ablation Study – Removing Dropout
#
# This experiment removes Dropout while keeping the deeper architecture and Batch Normalisation. The purpose is to examine whether Dropout helped control overfitting.

# %%
def build_ablation_no_dropout(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES):
    model = models.Sequential(name="Ablation_Deeper_CNN_No_Dropout")

    model.add(layers.Input(shape=input_shape))

    # Same deeper CNN structure, but without Dropout layers

    # Block 1
    model.add(layers.Conv2D(32, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Conv2D(32, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.MaxPooling2D((2, 2)))

    # Block 2
    model.add(layers.Conv2D(64, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Conv2D(64, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.MaxPooling2D((2, 2)))

    # Block 3
    model.add(layers.Conv2D(128, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.Conv2D(128, (3, 3), padding="same", activation=None))
    model.add(layers.BatchNormalization())
    model.add(layers.Activation("relu"))

    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())

    model.add(layers.Dense(256, activation="relu"))
    model.add(layers.Dense(128, activation="relu"))
    model.add(layers.Dense(num_classes, activation="softmax"))

    return model

# %%
ablation_model = build_ablation_no_dropout(
    input_shape=INPUT_SHAPE,
    num_classes=NUM_CLASSES
)

ablation_model.compile(
    optimizer=optimizers.Adam(learning_rate=5e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

ablation_model.summary()
# Out:
# Model: "Ablation_Deeper_CNN_No_Dropout"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_17 (Conv2D)              │ (None, 64, 64, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,419,431 (9.23 MB)
#  Trainable params: 2,418,535 (9.23 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
start_time = time.time()

ablation_history = ablation_model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=DEEPER_EPOCHS,
    callbacks=get_callbacks("deeper_cnn_no_dropout", patience=6),
    verbose=1
)

ablation_time = time.time() - start_time

print(f"Ablation model training time: {ablation_time:.2f} seconds")

plot_history(ablation_history, "Ablation Study: No Dropout")
# Out:
# Epoch 1/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2607 - loss: 1.9750
# Epoch 1: val_loss improved from None to 1.71619, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 1: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 48s 90ms/step - accuracy: 0.3058 - loss: 1.7562 - val_accuracy: 0.2942 - val_loss: 1.7162 - learning_rate: 5.0000e-04
# Epoch 2/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.3998 - loss: 1.5304
# Epoch 2: val_loss improved from 1.71619 to 1.48596, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 2: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.4240 - loss: 1.4798 - val_accuracy: 0.4372 - val_loss: 1.4860 - learning_rate: 5.0000e-04
# Epoch 3/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4645 - loss: 1.3855
# Epoch 3: val_loss improved from 1.48596 to 1.36450, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 3: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.4779 - loss: 1.3526 - val_accuracy: 0.4592 - val_loss: 1.3645 - learning_rate: 5.0000e-04
# Epoch 4/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5108 - loss: 1.2838
# Epoch 4: val_loss improved from 1.36450 to 1.29586, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 4: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.5145 - loss: 1.2697 - val_accuracy: 0.5031 - val_loss: 1.2959 - learning_rate: 5.0000e-04
# Epoch 5/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5339 - loss: 1.2285
# Epoch 5: val_loss improved from 1.29586 to 1.21665, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 5: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 76ms/step - accuracy: 0.5374 - loss: 1.2180 - val_accuracy: 0.5242 - val_loss: 1.2166 - learning_rate: 5.0000e-04
# Epoch 6/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5463 - loss: 1.1846
# Epoch 6: val_loss did not improve from 1.21665
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - accuracy: 0.5518 - loss: 1.1757 - val_accuracy: 0.5191 - val_loss: 1.2491 - learning_rate: 5.0000e-04
# Epoch 7/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5669 - loss: 1.1397
# Epoch 7: val_loss improved from 1.21665 to 1.18677, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 7: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.5618 - loss: 1.1441 - val_accuracy: 0.5515 - val_loss: 1.1868 - learning_rate: 5.0000e-04
# Epoch 8/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5714 - loss: 1.1260
# Epoch 8: val_loss did not improve from 1.18677
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.5739 - loss: 1.1148 - val_accuracy: 0.5497 - val_loss: 1.1931 - learning_rate: 5.0000e-04
# Epoch 9/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5892 - loss: 1.0762
# Epoch 9: val_loss improved from 1.18677 to 1.13506, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 9: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.5829 - loss: 1.0931 - val_accuracy: 0.5750 - val_loss: 1.1351 - learning_rate: 5.0000e-04
# Epoch 10/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5914 - loss: 1.0661
# Epoch 10: val_loss improved from 1.13506 to 1.10121, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 10: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.5904 - loss: 1.0711 - val_accuracy: 0.5859 - val_loss: 1.1012 - learning_rate: 5.0000e-04
# Epoch 11/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6007 - loss: 1.0530
# Epoch 11: val_loss did not improve from 1.10121
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 79ms/step - accuracy: 0.6007 - loss: 1.0490 - val_accuracy: 0.5822 - val_loss: 1.1054 - learning_rate: 5.0000e-04
# Epoch 12/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6007 - loss: 1.0493
# Epoch 12: val_loss improved from 1.10121 to 1.08337, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 12: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6050 - loss: 1.0378 - val_accuracy: 0.5948 - val_loss: 1.0834 - learning_rate: 5.0000e-04
# Epoch 13/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6234 - loss: 1.0071
# Epoch 13: val_loss improved from 1.08337 to 1.07335, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 13: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6158 - loss: 1.0184 - val_accuracy: 0.5991 - val_loss: 1.0733 - learning_rate: 5.0000e-04
# Epoch 14/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6186 - loss: 1.0027
# Epoch 14: val_loss did not improve from 1.07335
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 30s 72ms/step - accuracy: 0.6166 - loss: 1.0074 - val_accuracy: 0.5834 - val_loss: 1.1138 - learning_rate: 5.0000e-04
# Epoch 15/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6257 - loss: 0.9898
# Epoch 15: val_loss did not improve from 1.07335
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6244 - loss: 0.9923 - val_accuracy: 0.5852 - val_loss: 1.1061 - learning_rate: 5.0000e-04
# Epoch 16/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6408 - loss: 0.9484
# Epoch 16: val_loss improved from 1.07335 to 1.03992, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 16: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 34s 80ms/step - accuracy: 0.6456 - loss: 0.9430 - val_accuracy: 0.6145 - val_loss: 1.0399 - learning_rate: 2.5000e-04
# Epoch 17/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6399 - loss: 0.9322
# Epoch 17: val_loss improved from 1.03992 to 1.02408, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 17: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.6473 - loss: 0.9264 - val_accuracy: 0.6235 - val_loss: 1.0241 - learning_rate: 2.5000e-04
# Epoch 18/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6613 - loss: 0.9076
# Epoch 18: val_loss improved from 1.02408 to 1.01115, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 18: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6548 - loss: 0.9128 - val_accuracy: 0.6223 - val_loss: 1.0112 - learning_rate: 2.5000e-04
# Epoch 19/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6630 - loss: 0.8978
# Epoch 19: val_loss did not improve from 1.01115
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6624 - loss: 0.9035 - val_accuracy: 0.6170 - val_loss: 1.0411 - learning_rate: 2.5000e-04
# Epoch 20/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6612 - loss: 0.8945
# Epoch 20: val_loss did not improve from 1.01115
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 75ms/step - accuracy: 0.6613 - loss: 0.9008 - val_accuracy: 0.6008 - val_loss: 1.0665 - learning_rate: 2.5000e-04
# Epoch 21/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6745 - loss: 0.8580
# Epoch 21: val_loss improved from 1.01115 to 0.97385, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 21: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 33s 77ms/step - accuracy: 0.6739 - loss: 0.8648 - val_accuracy: 0.6432 - val_loss: 0.9739 - learning_rate: 1.2500e-04
# Epoch 22/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6776 - loss: 0.8539
# Epoch 22: val_loss did not improve from 0.97385
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6791 - loss: 0.8529 - val_accuracy: 0.6425 - val_loss: 0.9753 - learning_rate: 1.2500e-04
# Epoch 23/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6762 - loss: 0.8578
# Epoch 23: val_loss improved from 0.97385 to 0.95082, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 23: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.6802 - loss: 0.8517 - val_accuracy: 0.6458 - val_loss: 0.9508 - learning_rate: 1.2500e-04
# Epoch 24/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6822 - loss: 0.8365
# Epoch 24: val_loss did not improve from 0.95082
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.6839 - loss: 0.8400 - val_accuracy: 0.6469 - val_loss: 0.9698 - learning_rate: 1.2500e-04
# Epoch 25/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6823 - loss: 0.8467
# Epoch 25: val_loss did not improve from 0.95082
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 35s 84ms/step - accuracy: 0.6854 - loss: 0.8380 - val_accuracy: 0.6277 - val_loss: 1.0232 - learning_rate: 1.2500e-04
# Epoch 26/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6968 - loss: 0.8091
# Epoch 26: val_loss did not improve from 0.95082
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.6935 - loss: 0.8198 - val_accuracy: 0.6422 - val_loss: 0.9705 - learning_rate: 6.2500e-05
# Epoch 27/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6952 - loss: 0.8072
# Epoch 27: val_loss improved from 0.95082 to 0.94854, saving model to deeper_cnn_no_dropout.keras
#
# Epoch 27: finished saving model to deeper_cnn_no_dropout.keras
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.6937 - loss: 0.8136 - val_accuracy: 0.6510 - val_loss: 0.9485 - learning_rate: 6.2500e-05
# Epoch 28/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6960 - loss: 0.8104
# Epoch 28: val_loss did not improve from 0.94854
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.6953 - loss: 0.8084 - val_accuracy: 0.6459 - val_loss: 0.9720 - learning_rate: 6.2500e-05
# Epoch 29/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.7052 - loss: 0.7923
# Epoch 29: val_loss did not improve from 0.94854
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 35s 84ms/step - accuracy: 0.6970 - loss: 0.8059 - val_accuracy: 0.6415 - val_loss: 0.9899 - learning_rate: 6.2500e-05
# Epoch 30/30
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7003 - loss: 0.8010
# Epoch 30: val_loss did not improve from 0.94854
# 420/420 ━━━━━━━━━━━━━━━━━━━━ 32s 77ms/step - accuracy: 0.7002 - loss: 0.8011 - val_accuracy: 0.6400 - val_loss: 0.9702 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 27.
# Ablation model training time: 967.16 seconds

# %%
results.append(
    evaluate_model(ablation_model, test_gen, "Deeper CNN No Dropout")
)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 8s 207ms/step
#
# Deeper CNN No Dropout Evaluation
# Accuracy: 0.6021 | Precision: 0.6168 | Recall: 0.6021 | F1-score: 0.5923
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.54      0.54      0.54       300
#      disgust       0.91      0.32      0.47       100
#         fear       0.55      0.33      0.41       300
#        happy       0.74      0.85      0.80       300
#      neutral       0.48      0.76      0.59       300
#          sad       0.49      0.46      0.47       300
#     surprise       0.80      0.76      0.78       300
#
#     accuracy                           0.60      1900
#    macro avg       0.65      0.58      0.58      1900
# weighted avg       0.62      0.60      0.59      1900

# %% [markdown]
# ## 8. Part B – Transfer Learning with MobileNetV2
#
# MobileNetV2 is selected because it is lightweight and suitable for Colab GPU training. Since ImageNet models expect RGB images, grayscale facial images are loaded as RGB and resized to `96 × 96` for efficient transfer learning.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.efficientnet import preprocess_input

EFF_IMG_SIZE = (160, 160)
EFF_BATCH_SIZE = 32

eff_train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    width_shift_range=0.08,
    height_shift_range=0.08,
    zoom_range=0.08,
    horizontal_flip=True
)

eff_val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

eff_train_gen = eff_train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=EFF_IMG_SIZE,
    color_mode="rgb",
    batch_size=EFF_BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=SEED
)

eff_val_gen = eff_val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=EFF_IMG_SIZE,
    color_mode="rgb",
    batch_size=EFF_BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

eff_test_gen = eff_val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=EFF_IMG_SIZE,
    color_mode="rgb",
    batch_size=EFF_BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 26872 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.
# Found 1900 images belonging to 7 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models, optimizers
import tensorflow as tf

def build_efficientnet_model(num_classes=NUM_CLASSES):
    base_model = EfficientNetB0(
        weights="imagenet",
        include_top=False,
        input_shape=(160, 160, 3)
    )

    base_model.trainable = False

    inputs = layers.Input(shape=(160, 160, 3))

    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.40)(x)

    x = layers.Dense(256, activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Dropout(0.30)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs, outputs, name="EfficientNetB0_Transfer_Learning")

    return model, base_model


eff_model, eff_base = build_efficientnet_model()

eff_model.compile(
    optimizer=optimizers.Adam(learning_rate=3e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=["accuracy"]
)

eff_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "EfficientNetB0_Transfer_Learning"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 5, 5, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,841,642 (18.47 MB)
#  Trainable params: 790,535 (3.02 MB)
#  Non-trainable params: 4,051,107 (15.45 MB)

# %%
from tensorflow.keras import callbacks

def get_callbacks(model_name, patience=5, monitor="val_accuracy", mode="max"):
    return [
        callbacks.EarlyStopping(
            monitor=monitor,
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),
        callbacks.ModelCheckpoint(
            filepath=f"{model_name}.keras",
            monitor=monitor,
            save_best_only=True,
            mode=mode,
            verbose=1
        ),
        callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        )
    ]

# %%
import time

start_time = time.time()

eff_history = eff_model.fit(
    eff_train_gen,
    validation_data=eff_val_gen,
    epochs=15,
    callbacks=get_callbacks("efficientnetb0_transfer", patience=5),
    verbose=1
)

eff_time = time.time() - start_time

print(f"EfficientNetB0 frozen training time: {eff_time:.2f} seconds")

plot_history(eff_history, "EfficientNetB0 Transfer Learning")
# Out:
# Epoch 1/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.3057 - loss: 1.9188
# Epoch 1: val_accuracy improved from None to 0.44155, saving model to efficientnetb0_transfer.keras
#
# Epoch 1: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 258s 270ms/step - accuracy: 0.3533 - loss: 1.7634 - val_accuracy: 0.4416 - val_loss: 1.5013 - learning_rate: 3.0000e-04
# Epoch 2/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.4014 - loss: 1.6084
# Epoch 2: val_accuracy improved from 0.44155 to 0.46589, saving model to efficientnetb0_transfer.keras
#
# Epoch 2: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 187s 222ms/step - accuracy: 0.4093 - loss: 1.5875 - val_accuracy: 0.4659 - val_loss: 1.4541 - learning_rate: 3.0000e-04
# Epoch 3/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4271 - loss: 1.5377
# Epoch 3: val_accuracy improved from 0.46589 to 0.47608, saving model to efficientnetb0_transfer.keras
#
# Epoch 3: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 186s 222ms/step - accuracy: 0.4326 - loss: 1.5249 - val_accuracy: 0.4761 - val_loss: 1.4305 - learning_rate: 3.0000e-04
# Epoch 4/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.4529 - loss: 1.4878
# Epoch 4: val_accuracy improved from 0.47608 to 0.48344, saving model to efficientnetb0_transfer.keras
#
# Epoch 4: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 185s 220ms/step - accuracy: 0.4545 - loss: 1.4776 - val_accuracy: 0.4834 - val_loss: 1.4134 - learning_rate: 3.0000e-04
# Epoch 5/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4659 - loss: 1.4555
# Epoch 5: val_accuracy improved from 0.48344 to 0.49151, saving model to efficientnetb0_transfer.keras
#
# Epoch 5: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 186s 222ms/step - accuracy: 0.4687 - loss: 1.4495 - val_accuracy: 0.4915 - val_loss: 1.3999 - learning_rate: 3.0000e-04
# Epoch 6/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4828 - loss: 1.4202
# Epoch 6: val_accuracy did not improve from 0.49151
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 185s 220ms/step - accuracy: 0.4797 - loss: 1.4259 - val_accuracy: 0.4851 - val_loss: 1.4162 - learning_rate: 3.0000e-04
# Epoch 7/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4846 - loss: 1.4191
# Epoch 7: val_accuracy improved from 0.49151 to 0.49207, saving model to efficientnetb0_transfer.keras
#
# Epoch 7: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 186s 221ms/step - accuracy: 0.4847 - loss: 1.4174 - val_accuracy: 0.4921 - val_loss: 1.3952 - learning_rate: 3.0000e-04
# Epoch 8/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.4961 - loss: 1.4060
# Epoch 8: val_accuracy improved from 0.49207 to 0.50425, saving model to efficientnetb0_transfer.keras
#
# Epoch 8: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 185s 221ms/step - accuracy: 0.4934 - loss: 1.4017 - val_accuracy: 0.5042 - val_loss: 1.3725 - learning_rate: 3.0000e-04
# Epoch 9/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4918 - loss: 1.3975
# Epoch 9: val_accuracy did not improve from 0.50425
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 185s 221ms/step - accuracy: 0.4949 - loss: 1.3938 - val_accuracy: 0.4987 - val_loss: 1.3811 - learning_rate: 3.0000e-04
# Epoch 10/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.4975 - loss: 1.3887
# Epoch 10: val_accuracy improved from 0.50425 to 0.50736, saving model to efficientnetb0_transfer.keras
#
# Epoch 10: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 184s 219ms/step - accuracy: 0.5049 - loss: 1.3824 - val_accuracy: 0.5074 - val_loss: 1.3598 - learning_rate: 3.0000e-04
# Epoch 11/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.5119 - loss: 1.3672
# Epoch 11: val_accuracy improved from 0.50736 to 0.51302, saving model to efficientnetb0_transfer.keras
#
# Epoch 11: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 183s 218ms/step - accuracy: 0.5071 - loss: 1.3726 - val_accuracy: 0.5130 - val_loss: 1.3541 - learning_rate: 3.0000e-04
# Epoch 12/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.5085 - loss: 1.3663
# Epoch 12: val_accuracy did not improve from 0.51302
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 183s 218ms/step - accuracy: 0.5086 - loss: 1.3693 - val_accuracy: 0.5109 - val_loss: 1.3600 - learning_rate: 3.0000e-04
# Epoch 13/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.5062 - loss: 1.3686
# Epoch 13: val_accuracy improved from 0.51302 to 0.52307, saving model to efficientnetb0_transfer.keras
#
# Epoch 13: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 184s 219ms/step - accuracy: 0.5119 - loss: 1.3597 - val_accuracy: 0.5231 - val_loss: 1.3430 - learning_rate: 3.0000e-04
# Epoch 14/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.5171 - loss: 1.3465
# Epoch 14: val_accuracy improved from 0.52307 to 0.52547, saving model to efficientnetb0_transfer.keras
#
# Epoch 14: finished saving model to efficientnetb0_transfer.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 183s 218ms/step - accuracy: 0.5143 - loss: 1.3559 - val_accuracy: 0.5255 - val_loss: 1.3384 - learning_rate: 3.0000e-04
# Epoch 15/15
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.5218 - loss: 1.3419
# Epoch 15: val_accuracy did not improve from 0.52547
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 183s 218ms/step - accuracy: 0.5223 - loss: 1.3444 - val_accuracy: 0.5219 - val_loss: 1.3399 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 14.
# EfficientNetB0 frozen training time: 2845.59 seconds

# %%
# EfficientNetB0 Fine-Tuning

import time
import tensorflow as tf
from tensorflow.keras import layers, optimizers, callbacks
from tensorflow.keras.models import load_model


# 1. Load best frozen EfficientNetB0 checkpoint


eff_model = load_model("efficientnetb0_transfer.keras")
print("Loaded best frozen EfficientNetB0 model.")



# 2. Find EfficientNetB0 base layer automatically


eff_base = None

for layer in eff_model.layers:
    if "efficientnet" in layer.name.lower():
        eff_base = layer
        break

if eff_base is None:
    print("Available layers:")
    for layer in eff_model.layers:
        print(layer.name)
    raise ValueError("EfficientNetB0 base layer not found.")

print("EfficientNet base layer found:", eff_base.name)



# 3. Universal fine-tuning callback


def get_finetune_callbacks(model_name, patience=5):
    return [
        callbacks.ModelCheckpoint(
            filepath=f"{model_name}.keras",
            monitor="val_accuracy",
            save_best_only=True,
            mode="max",
            verbose=1
        ),

        callbacks.EarlyStopping(
            monitor="val_accuracy",
            patience=patience,
            restore_best_weights=True,
            mode="max",
            verbose=1
        ),

        callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=2,
            min_lr=1e-7,
            verbose=1
        )
    ]



# STAGE 1: Careful fine-tuning of last 25 layers


eff_base.trainable = True

# Freeze most EfficientNet layers
for layer in eff_base.layers[:-25]:
    layer.trainable = False

# Keep BatchNorm layers frozen for stable transfer learning
for layer in eff_base.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

print("\nStage 1 trainable EfficientNet layers:")
stage1_trainable = 0

for layer in eff_base.layers:
    if layer.trainable:
        stage1_trainable += 1
        print(layer.name)

print("Total trainable base layers in Stage 1:", stage1_trainable)


eff_model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-5),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.03),
    metrics=["accuracy"]
)

eff_model.summary()


start_time = time.time()

eff_finetune_history_1 = eff_model.fit(
    eff_train_gen,
    validation_data=eff_val_gen,
    epochs=10,
    callbacks=get_finetune_callbacks("efficientnetb0_finetuned_stage1", patience=5),
    verbose=1
)

stage1_time = time.time() - start_time

print(f"EfficientNetB0 Stage 1 fine-tuning time: {stage1_time:.2f} seconds")

plot_history(eff_finetune_history_1, "EfficientNetB0 Fine-Tuning Stage 1")



# STAGE 2: Slightly deeper fine-tuning of last 50 layers
# Only starts from best Stage 1 checkpoint


eff_model = load_model("efficientnetb0_finetuned_stage1.keras")

# Find base layer again after loading
eff_base = None

for layer in eff_model.layers:
    if "efficientnet" in layer.name.lower():
        eff_base = layer
        break

if eff_base is None:
    raise ValueError("EfficientNetB0 base layer not found after loading Stage 1 model.")


eff_base.trainable = True

# Fine-tune last 50 layers
for layer in eff_base.layers[:-50]:
    layer.trainable = False

# Keep BatchNorm frozen
for layer in eff_base.layers:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

print("\nStage 2 trainable EfficientNet layers:")
stage2_trainable = 0

for layer in eff_base.layers:
    if layer.trainable:
        stage2_trainable += 1
        print(layer.name)

print("Total trainable base layers in Stage 2:", stage2_trainable)


eff_model.compile(
    optimizer=optimizers.Adam(learning_rate=3e-6),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.03),
    metrics=["accuracy"]
)

eff_model.summary()


start_time = time.time()

eff_finetune_history_2 = eff_model.fit(
    eff_train_gen,
    validation_data=eff_val_gen,
    epochs=10,
    callbacks=get_finetune_callbacks("efficientnetb0_finetuned_final", patience=5),
    verbose=1
)

stage2_time = time.time() - start_time

print(f"EfficientNetB0 Stage 2 fine-tuning time: {stage2_time:.2f} seconds")

plot_history(eff_finetune_history_2, "EfficientNetB0 Fine-Tuning Stage 2")



# 4. Evaluate the best final fine-tuned model


best_eff_model = load_model("efficientnetb0_finetuned_final.keras")

print("Evaluating best final fine-tuned EfficientNetB0 model...")

eff_test_loss, eff_test_acc = best_eff_model.evaluate(eff_test_gen)

print("Best Fine-Tuned EfficientNetB0 Test Accuracy:", eff_test_acc)
print("Best Fine-Tuned EfficientNetB0 Test Loss:", eff_test_loss)



# 5. Add result to results list


results.append(
    evaluate_model(
        best_eff_model,
        eff_test_gen,
        "Fine-Tuned EfficientNetB0"
    )
)
# Out:
# Loaded best frozen EfficientNetB0 model.
# EfficientNet base layer found: efficientnetb0
#
# Stage 1 trainable EfficientNet layers:
# block6d_se_squeeze
# block6d_se_reshape
# block6d_se_reduce
# block6d_se_expand
# block6d_se_excite
# block6d_project_conv
# block6d_drop
# block6d_add
# block7a_expand_conv
# block7a_expand_activation
# block7a_dwconv
# block7a_activation
# block7a_se_squeeze
# block7a_se_reshape
# block7a_se_reduce
# block7a_se_expand
# block7a_se_excite
# block7a_project_conv
# top_conv
# top_activation
# Total trainable base layers in Stage 1: 20
# Model: "EfficientNetB0_Transfer_Learning"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 5, 5, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,841,642 (18.47 MB)
#  Trainable params: 2,245,095 (8.56 MB)
#  Non-trainable params: 2,596,547 (9.91 MB)
# Epoch 1/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.5253 - loss: 1.3021
# Epoch 1: val_accuracy improved from None to 0.53581, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 1: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 239s 251ms/step - accuracy: 0.5323 - loss: 1.2897 - val_accuracy: 0.5358 - val_loss: 1.2781 - learning_rate: 1.0000e-05
# Epoch 2/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.5362 - loss: 1.2704
# Epoch 2: val_accuracy improved from 0.53581 to 0.54359, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 2: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 186s 222ms/step - accuracy: 0.5373 - loss: 1.2713 - val_accuracy: 0.5436 - val_loss: 1.2664 - learning_rate: 1.0000e-05
# Epoch 3/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.5489 - loss: 1.2485
# Epoch 3: val_accuracy improved from 0.54359 to 0.54798, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 3: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 187s 222ms/step - accuracy: 0.5475 - loss: 1.2506 - val_accuracy: 0.5480 - val_loss: 1.2515 - learning_rate: 1.0000e-05
# Epoch 4/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.5491 - loss: 1.2436
# Epoch 4: val_accuracy improved from 0.54798 to 0.55293, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 4: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 187s 223ms/step - accuracy: 0.5511 - loss: 1.2398 - val_accuracy: 0.5529 - val_loss: 1.2411 - learning_rate: 1.0000e-05
# Epoch 5/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.5562 - loss: 1.2284
# Epoch 5: val_accuracy improved from 0.55293 to 0.55350, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 5: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 185s 220ms/step - accuracy: 0.5569 - loss: 1.2279 - val_accuracy: 0.5535 - val_loss: 1.2344 - learning_rate: 1.0000e-05
# Epoch 6/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.5650 - loss: 1.2152
# Epoch 6: val_accuracy improved from 0.55350 to 0.55703, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 6: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 191s 227ms/step - accuracy: 0.5647 - loss: 1.2142 - val_accuracy: 0.5570 - val_loss: 1.2281 - learning_rate: 1.0000e-05
# Epoch 7/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5666 - loss: 1.2127
# Epoch 7: val_accuracy did not improve from 0.55703
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 187s 223ms/step - accuracy: 0.5684 - loss: 1.2065 - val_accuracy: 0.5570 - val_loss: 1.2224 - learning_rate: 1.0000e-05
# Epoch 8/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.5721 - loss: 1.1992
# Epoch 8: val_accuracy improved from 0.55703 to 0.56383, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 8: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 195s 232ms/step - accuracy: 0.5685 - loss: 1.2022 - val_accuracy: 0.5638 - val_loss: 1.2180 - learning_rate: 1.0000e-05
# Epoch 9/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.5737 - loss: 1.1937
# Epoch 9: val_accuracy improved from 0.56383 to 0.56836, saving model to efficientnetb0_finetuned_stage1.keras
#
# Epoch 9: finished saving model to efficientnetb0_finetuned_stage1.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 198s 235ms/step - accuracy: 0.5729 - loss: 1.1924 - val_accuracy: 0.5684 - val_loss: 1.2101 - learning_rate: 1.0000e-05
# Epoch 10/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.5725 - loss: 1.1909
# Epoch 10: val_accuracy did not improve from 0.56836
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 194s 231ms/step - accuracy: 0.5761 - loss: 1.1850 - val_accuracy: 0.5682 - val_loss: 1.2050 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 9.
# EfficientNetB0 Stage 1 fine-tuning time: 1949.01 seconds
# Stage 2 trainable EfficientNet layers:
# block6d_se_squeeze
# block6d_se_reshape
# block6d_se_reduce
# block6d_se_expand
# block6d_se_excite
# block6d_project_conv
# block6d_drop
# block6d_add
# block7a_expand_conv
# block7a_expand_activation
# block7a_dwconv
# block7a_activation
# block7a_se_squeeze
# block7a_se_reshape
# block7a_se_reduce
# block7a_se_expand
# block7a_se_excite
# block7a_project_conv
# top_conv
# top_activation
# Total trainable base layers in Stage 2: 20
# Model: "EfficientNetB0_Transfer_Learning"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 160, 160, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 5, 5, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,841,642 (18.47 MB)
#  Trainable params: 2,245,095 (8.56 MB)
#  Non-trainable params: 2,596,547 (9.91 MB)
# Epoch 1/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.5818 - loss: 1.1776
# Epoch 1: val_accuracy improved from None to 0.56906, saving model to efficientnetb0_finetuned_final.keras
#
# Epoch 1: finished saving model to efficientnetb0_finetuned_final.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 248s 262ms/step - accuracy: 0.5765 - loss: 1.1821 - val_accuracy: 0.5691 - val_loss: 1.2073 - learning_rate: 3.0000e-06
# Epoch 2/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5801 - loss: 1.1810
# Epoch 2: val_accuracy did not improve from 0.56906
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 195s 232ms/step - accuracy: 0.5797 - loss: 1.1841 - val_accuracy: 0.5679 - val_loss: 1.2055 - learning_rate: 3.0000e-06
# Epoch 3/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5819 - loss: 1.1780
# Epoch 3: val_accuracy did not improve from 0.56906
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 195s 233ms/step - accuracy: 0.5815 - loss: 1.1762 - val_accuracy: 0.5691 - val_loss: 1.2040 - learning_rate: 3.0000e-06
# Epoch 4/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.5834 - loss: 1.1733
# Epoch 4: val_accuracy improved from 0.56906 to 0.56949, saving model to efficientnetb0_finetuned_final.keras
#
# Epoch 4: finished saving model to efficientnetb0_finetuned_final.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 195s 231ms/step - accuracy: 0.5806 - loss: 1.1783 - val_accuracy: 0.5695 - val_loss: 1.2015 - learning_rate: 3.0000e-06
# Epoch 5/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5835 - loss: 1.1649
# Epoch 5: val_accuracy did not improve from 0.56949
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 189s 225ms/step - accuracy: 0.5804 - loss: 1.1745 - val_accuracy: 0.5695 - val_loss: 1.2014 - learning_rate: 3.0000e-06
# Epoch 6/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5770 - loss: 1.1812
# Epoch 6: val_accuracy improved from 0.56949 to 0.57062, saving model to efficientnetb0_finetuned_final.keras
#
# Epoch 6: finished saving model to efficientnetb0_finetuned_final.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 195s 232ms/step - accuracy: 0.5797 - loss: 1.1791 - val_accuracy: 0.5706 - val_loss: 1.1989 - learning_rate: 3.0000e-06
# Epoch 7/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.5775 - loss: 1.1779
# Epoch 7: val_accuracy did not improve from 0.57062
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 196s 233ms/step - accuracy: 0.5812 - loss: 1.1761 - val_accuracy: 0.5692 - val_loss: 1.1992 - learning_rate: 3.0000e-06
# Epoch 8/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5883 - loss: 1.1646
# Epoch 8: val_accuracy improved from 0.57062 to 0.57204, saving model to efficientnetb0_finetuned_final.keras
#
# Epoch 8: finished saving model to efficientnetb0_finetuned_final.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 193s 229ms/step - accuracy: 0.5876 - loss: 1.1661 - val_accuracy: 0.5720 - val_loss: 1.1959 - learning_rate: 3.0000e-06
# Epoch 9/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5873 - loss: 1.1663
# Epoch 9: val_accuracy did not improve from 0.57204
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 191s 227ms/step - accuracy: 0.5841 - loss: 1.1687 - val_accuracy: 0.5696 - val_loss: 1.1963 - learning_rate: 3.0000e-06
# Epoch 10/10
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5822 - loss: 1.1639
# Epoch 10: val_accuracy improved from 0.57204 to 0.57444, saving model to efficientnetb0_finetuned_final.keras
#
# Epoch 10: finished saving model to efficientnetb0_finetuned_final.keras
# 840/840 ━━━━━━━━━━━━━━━━━━━━ 191s 227ms/step - accuracy: 0.5859 - loss: 1.1608 - val_accuracy: 0.5744 - val_loss: 1.1923 - learning_rate: 3.0000e-06
# Restoring model weights from the end of the best epoch: 10.
# EfficientNetB0 Stage 2 fine-tuning time: 1988.55 seconds
# Evaluating best final fine-tuned EfficientNetB0 model...
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 24s 229ms/step - accuracy: 0.5137 - loss: 1.3533
# Best Fine-Tuned EfficientNetB0 Test Accuracy: 0.5136842131614685
# Best Fine-Tuned EfficientNetB0 Test Loss: 1.3532782793045044
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 16s 160ms/step
#
# Fine-Tuned EfficientNetB0 Evaluation
# Accuracy: 0.5137 | Precision: 0.5472 | Recall: 0.5137 | F1-score: 0.4916
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry       0.46      0.42      0.44       300
#      disgust       1.00      0.09      0.17       100
#         fear       0.54      0.20      0.29       300
#        happy       0.60      0.82      0.69       300
#      neutral       0.48      0.54      0.51       300
#          sad       0.36      0.55      0.43       300
#     surprise       0.70      0.70      0.70       300
#
#     accuracy                           0.51      1900
#    macro avg       0.59      0.47      0.46      1900
# weighted avg       0.55      0.51      0.49      1900

# %% [markdown]
# ## 9. Final Comparative Analysis
#
# This table compares accuracy, precision, recall, F1-score, prediction time, and training time. Use these results in the final report to discuss performance, computational efficiency and trade-offs.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Final comparison table using saved evaluation results
results_df = pd.DataFrame([
    {
        'model': 'Baseline CNN',
        'accuracy': 0.5337,
        'precision': 0.5318,
        'recall': 0.5337,
        'f1': 0.5285,
        'training_time_sec': 610.28
    },
    {
        'model': 'Deeper CNN with Adam',
        'accuracy': 0.5158,
        'precision': 0.4857,
        'recall': 0.5158,
        'f1': 0.4901,
        'training_time_sec': 1002.94
    },
    {
        'model': 'Deeper CNN with SGD',
        'accuracy': 0.5011,
        'precision': 0.5429,
        'recall': 0.5011,
        'f1': 0.4773,
        'training_time_sec': 998.44
    },
    {
        'model': 'Deeper CNN No Dropout',
        'accuracy': 0.6021,
        'precision': 0.6168,
        'recall': 0.6021,
        'f1': 0.5923,
        'training_time_sec': 967.16
    },
    {
        'model': 'EfficientNetB0 Frozen Transfer Learning',
        'accuracy': 0.5255,
        'precision': 0.5255,
        'recall': 0.5255,
        'f1': 0.5255,
        'training_time_sec': 2845.59
    },
    {
        'model': 'EfficientNetB0 Fine-Tuning Stage 1',
        'accuracy': 0.5684,
        'precision': 0.5684,
        'recall': 0.5684,
        'f1': 0.5684,
        'training_time_sec': 1949.01
    },
    {
        'model': 'EfficientNetB0 Fine-Tuning Stage 2',
        'accuracy': 0.5137,
        'precision': 0.5472,
        'recall': 0.5137,
        'f1': 0.4916,
        'training_time_sec': 1988.55
    }
])

# Display table sorted by F1-score
display(results_df.sort_values('f1', ascending=False).reset_index(drop=True))

# Accuracy comparison
plt.figure(figsize=(12, 5))
plt.bar(results_df['model'], results_df['accuracy'])
plt.title('Model Accuracy Comparison')
plt.ylabel('Test Accuracy')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# F1-score comparison
plt.figure(figsize=(12, 5))
plt.bar(results_df['model'], results_df['f1'])
plt.title('Model F1-Score Comparison')
plt.ylabel('F1-score')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)
plt.tight_layout()
plt.show()

# Training time comparison
plt.figure(figsize=(12, 5))
plt.bar(results_df['model'], results_df['training_time_sec'])
plt.title('Training Time Comparison')
plt.ylabel('Training Time (seconds)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
#                                      model  accuracy  precision  recall  \
# 0                    Deeper CNN No Dropout    0.6021     0.6168  0.6021
# 1       EfficientNetB0 Fine-Tuning Stage 1    0.5684     0.5684  0.5684
# 2                             Baseline CNN    0.5337     0.5318  0.5337
# 3  EfficientNetB0 Frozen Transfer Learning    0.5255     0.5255  0.5255
# 4       EfficientNetB0 Fine-Tuning Stage 2    0.5137     0.5472  0.5137
# 5                     Deeper CNN with Adam    0.5158     0.4857  0.5158
# 6                      Deeper CNN with SGD    0.5011     0.5429  0.5011
#
#        f1  training_time_sec
# 0  0.5923             967.16
# 1  0.5684            1949.01
# 2  0.5285             610.28
# 3  0.5255            2845.59
# 4  0.4916            1988.55
# 5  0.4901            1002.94
# 6  0.4773             998.44
